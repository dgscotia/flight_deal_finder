# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("heat_cost.csv")

# %%
df
# Out:
#            Country range  Gas condensing boiler (2019 gas prices)  \
# 0           Canada   low                                       31
# 1           Canada  high                                       48
# 2          Denmark   low                                       82
# 3          Denmark  high                                      133
# 4           France   low                                       91
# 5           France  high                                      143
# 6          Germany   low                                       72
# 7          Germany  high                                      125
# 8   United Kingdom   low                                       57
# 9   United Kingdom  high                                       97
# 10          Sweden   low                                      124
# 11          Sweden  high                                      193
#
#     Gas condensing boiler (gas prices 30% higher than 2019)  Pellet boiler  \
# ...

# %%
df_mean = df.groupby("Country").mean()
df_mean
# Out:
#                 Gas condensing boiler (2019 gas prices)  \
# Country
# Canada                                             39.5
# Denmark                                           107.5
# France                                            117.0
# Germany                                            98.5
# Sweden                                            158.5
# United Kingdom                                     77.0
#
#                 Gas condensing boiler (gas prices 30% higher than 2019)  \
# Country
# Canada                                                       44.0
# Denmark                                                     129.5
# France                                                      138.5
# Germany                                                     122.0
# Sweden                                                      188.5
# United Kingdom                                               90.5
#
#                 Pellet boiler  Electric air-air heat pump  \
# Country
# ...

# %%
# sns.barplot(x=df_mean.index)
sns.set_style("whitegrid")
sns.catplot(x="Country", y="Electric air-air heat pump", data=df_mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26996/1846641863.py in <module>
#       1 # sns.barplot(x=df_mean.index)
#       2 sns.set_style("whitegrid")
# ----> 3 sns.catplot(x="Country", y="Electric air-air heat pump", data=df_mean)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
